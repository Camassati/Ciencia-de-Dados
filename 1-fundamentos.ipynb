# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])

# %%
arr F:\RENTABILIDADE\Udemy Py\1-fundamentos.ipynb
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
soma = arr + 10
print("Array após somar 10:", soma)
# Out:
# Array após somar 10: [11 12 13 14 15]

# %%
soma = arr * 2
print("Array após multiplicar 2:", soma)
# Out:
# Array após multiplicar 2: [ 2  4  6  8 10]

# %%
media = np.mean(arr)
print("Média do array:", media)
# Out:
# Média do array: 3.0
