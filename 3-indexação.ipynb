# %%
import numpy as np

# %%
array = np.array([
    [10,20,30],
    [40,50,60],
    [70,80,90]
])
print(array.ndim)
print(array.shape)

array
# Out:
# 2
# (3, 3)
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
elemento = array[1,2]
elemento
# Out:
# np.int64(60)

# %%
linha_0 = array[0]

coluna_0 = array[:,0]

coluna_0
linha_0
# Out:
# array([10, 20, 30])
