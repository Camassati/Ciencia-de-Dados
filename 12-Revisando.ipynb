# %%
import numpy as np

# %%
nomes = np.array(["Gustavo","Mateus","Saulo","Davi","Junior"])
notas_matematicas = np.array([55,67,72,48,90])
notas_fisica = np.array([88,76,95,64,70])

# %%
media = np.mean(np.column_stack((notas_matematicas,notas_fisica)),axis =1 )
media
# Out:
# array([71.5, 71.5, 83.5, 56. , 80. ])

# %%
#identificando alunos aprovados
alunos_aprovados = np.where(media>60)
alunos_aprovados
# Out:
# (array([0, 1, 2, 4]),)

# %%
# Organizando os dados na tabela
dados_tabela = np.column_stack((nomes,notas_matematicas,notas_fisica,media))
dados_tabela
# Out:
# array([['Gustavo', '55', '88', '71.5'],
#        ['Mateus', '67', '76', '71.5'],
#        ['Saulo', '72', '95', '83.5'],
#        ['Davi', '48', '64', '56.0'],
#        ['Junior', '90', '70', '80.0']], dtype='<U32')

# %%
# Exibindo alunos aprovados

for i in alunos_aprovados[0]:
    print(f"{dados_tabela[i][0]}- Média: {media[i]:.2f}")
# Out:
# Gustavo- Média: 71.50
# Mateus- Média: 71.50
# Saulo- Média: 83.50
# Junior- Média: 80.00

# %%
#Dividindo alunos em grupos
grupos = np.array_split(nomes,3)
for i,value in enumerate(grupos):
    print(f"Grupo {i+1}: {value}")
# Out:
# Grupo 1: ['Gustavo' 'Mateus']
# Grupo 2: ['Saulo' 'Davi']
# Grupo 3: ['Junior']
